# %%
#Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from config import g_key

#Loading dataframe from WeatherPy
cities_df = pd.read_csv("../WeatherPy/output_data.csv")
cities_df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Esperance         100      AU  1583994880        64 -33.87  121.90
# 1  Saskylakh          99      RU  1583994933        91  71.92  114.08
# 2   Bhandāra          20      IN  1583994902        48  21.17   79.65
# 3       Hilo          90      US  1583994884        78  19.73 -155.09
# 4    Ushuaia          90      AR  1583994621        93 -54.80  -68.30
#
#    Max Temp  Wind Speed
# 0    73.436   21.922012
# 1     3.596   16.978375
# 2    84.236    3.355410
# 3    71.636    5.748936
# 4    46.436    4.697574

# %%
#Configure google maps
gmaps.configure(api_key=g_key)

#Create Heatmap using coordinates of cities and humidities as weight
locations = cities_df[['Lat', 'Lng']]
weights = cities_df['Humidity']
figure_layout = {
    'width': '600px',
    'height': '600px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='600px', margin='0 auto 0 auto', padding='1px', wi…

# %%
#Create New DataFrame fitting Weather Criteria
#Max Temp greater than 70, less than 80
temp_df = cities_df[(cities_df['Max Temp'] > 70) & (cities_df['Max Temp'] < 80)]

#Wind speed less than 10mph
wind_df = temp_df[(temp_df['Wind Speed'] < 10)]

#No clouds
ideal_df = wind_df[(wind_df['Cloudiness'] == 0)]
ideal_df
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 30       Panabá           0      MX  1583995095        86  21.28  -88.27
# 64        Mīnāb           0      IR  1583995105        50  27.15   57.08
# 124         Sur           0      OM  1583995037        28  22.57   59.53
# 254  São Filipe           0      CV  1583994930        64  14.90  -24.50
# 294     Tuy Hoa           0      VN  1583995166        82  13.08  109.30
# 553         Diu           0      IN  1583995236        51  20.71   70.98
# 557       Nioro           0      GM  1583995237        15  13.35  -15.75
#
#      Max Temp  Wind Speed
# 30     70.952    6.621342
# 64     75.236    4.697574
# 124    75.434    8.120092
# 254    73.670    6.285801
# 294    77.702    4.585727
# 553    71.636    1.700074
# 557    71.672    3.959384
